# %% [markdown]
# # Chapter 0: Welcome
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abderrahim-lectures/build-up/blob/master/notebooks/ch00_welcome.ipynb)
#
# Welcome to **Build Up: Python for Little Geniuses**! This notebook runs right here in your browser -- nothing to install.
#
# **By the end of this chapter you can:**
# - Run a line of Python code and see what it does
# - Explain what `print()` does
# - Find your way around this book (see `book/00-welcome/01-how-to-read-this-book.tex`)

# %% [markdown]
# ## Try it yourself
#
# Click the code cell below, then press **Shift + Enter** to run it.

# %%
print("Welcome, Little Genius! You just ran your first line of Python.")

# %% [markdown]
# ## Now make it your own
#
# Change `"Little Genius"` in the code below to your own name, then run it.

# %%
def greet(name):
    return f"Welcome, {name}! You just ran your first line of Python."


print(greet("Little Genius"))

# %% [markdown]
# ## Check My Knowledge
#
# 1. What word did Python print when you ran the first code cell?
# 2. What happens if you change the text inside `greet("...")`?
#
# *(Answers: this is a "not yet" zone -- there's no wrong guess here, just try it and see!)*
