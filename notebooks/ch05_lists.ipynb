# %% [markdown]
# # Chapter 5: Lists
#
# [![Launch on MyBinder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/abderrahim-lectures/build-up-python-for-little-geniuses/master?filepath=notebooks/ch05_lists.ipynb)
#
# A list is an ordered sequence of values, the same idea as a numbered sequence in math – item 1, item 2, item 3.
#
# **By the end of this chapter you can:**
# - Create a list and add items with append()
# - Access an item by its index
# - Explain why Python lists start counting at 0

# %% [markdown]
# ## Try it yourself
#
# Add your own item to the inventory below.

# %%
inventory = ["sword", "shield"]
inventory.append("potion")
print(inventory)
print(inventory[0])
print(len(inventory))

# %% [markdown]
# ## Now make it your own

# %%
def add_item(inventory, item):
    return inventory + [item]


print(add_item(inventory, "map"))

# %% [markdown]
# ## Check My Knowledge
#
# 1. What index gets the FIRST item in a list?
# 2. What does append() do to a list?
# 3. After three appends to an empty list, what index holds the very first item you added, and does that ever change?
#
# *(Answers: this is a "not yet" zone – there's no wrong guess here, just try it and see!)*
