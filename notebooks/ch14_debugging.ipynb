# %% [markdown]
# # Chapter 14: Debugging
#
# [![Launch on MyBinder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/abderrahim-lectures/build-up-python-for-little-geniuses/master?filepath=notebooks/ch14_debugging.ipynb)
#
# Checking your work – the same habit from math class – is what debugging and testing are: verifying your code's answer is actually right.
#
# **By the end of this chapter you can:**
# - Read a Python traceback to find where an error happened
# - Write a pytest test that checks a function's answer
# - Fix a bug using print() to inspect a variable's value

# %% [markdown]
# ## Try it yourself
#
# Try calling safe_divide with b = 0 below – it shouldn't crash.

# %%
def safe_divide(a, b):
    if b == 0:
        return None
    return a / b


print(safe_divide(10, 2))
print(safe_divide(10, 0))

# %% [markdown]
# ## Check My Knowledge
#
# 1. Where in a traceback do you usually find the actual error message?
# 2. What does assert do in a pytest test?
# 3. Why does test_safe_divide_by_zero_returns_none check `is None` instead of `== None`? (Hint: try both in a notebook cell and see if Python warns you.)
#
# *(Answers: this is a "not yet" zone – there's no wrong guess here, just try it and see!)*
